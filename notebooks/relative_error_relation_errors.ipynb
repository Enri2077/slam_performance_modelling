# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import ipywidgets as widgets
from ipywidgets import interact, interact_manual
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import numpy as np
import scipy.stats as ss
import pandas as pd
from os import path
import glob
import pickle
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [25, 13]
pd.options.display.width = 500
n_bins_default = 15
x = np.arange(0, 2, 0.01)

# %%
errors = pd.DataFrame()

errors_files_dir = "/home/enrico/ds/performance_modelling/output/test_slam/session_2020-10-21_08-23-49_358145_run_000000071/logs/relative_localisation_error"
for i in [0]: #range(len(glob.glob(path.join(errors_files_dir, '*')))):
    errors_file_path = path.join(errors_files_dir, "waypoint_{}".format(i), "re_t_unsorted_errors")
    if path.exists(errors_file_path):
        errors = errors.append(pd.read_csv(errors_file_path, header=None))

plt.hist(errors, x)
plt.suptitle("single relation errors in one run (computed per waypoint), Our")
plt.show()
len(errors)
# Out:
# 901

# %%
errors_file_path = "/home/enrico/ds/performance_modelling/output/test_slam/session_2020-10-21_08-23-49_358145_run_000000071/logs/relative_localization_error_overall/re_t_unsorted_errors"
errors = pd.read_csv(errors_file_path, header=None)

plt.hist(errors, x)
plt.suptitle("single relation errors in one run (computed on the whole run), Our")
plt.show()
len(errors)
# Out:
# 264439

# %%
errors_file_path = "/home/enrico/ds/ext/SLAMigoni/runs/training/gmapping/realistic/130604-Plan_updated/run1/Errors/Original/RE/T-unsorted.errors"
errors = pd.read_csv(errors_file_path, header=None)

plt.hist(errors, x)
plt.suptitle("single relation errors in one run (computed on the whole run), Amigoni")
plt.show()
len(errors)
# Out:
# 4961
